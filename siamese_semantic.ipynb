# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/zacateras/deep-siamese-text-similarity/blob/wedt/siamese_semantic.ipynb)

# %%
# If python3 is not loaded kill the hypervisor# If py 
# ! kill -9 -1
import sys
sys.version

# %%
! git clone -b wedt https://github.com/zacateras/deep-siamese-text-similarity.git
# Out:
# Cloning into 'deep-siamese-text-similarity'...
# remote: Counting objects: 117, done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 117 (delta 0), reused 6 (delta 0), pack-reused 107
# Receiving objects: 100% (117/117), 2.47 MiB | 20.05 MiB/s, done.
# Resolving deltas: 100% (59/59), done.

# %%
% cd ./deep-siamese-text-similarity
! pip install -r requirements.txt > pip.log
# Out:
# /content/deep-siamese-text-similarity
# opencv-python 3.4.0.12 has requirement numpy>=1.11.1, but you'll have numpy 1.11.0 which is incompatible.
# tensorboard 1.7.0 has requirement numpy>=1.12.0, but you'll have numpy 1.11.0 which is incompatible.

# %%
! mkdir "data"

# Download word2vec model
! wget "https://s3-us-west-1.amazonaws.com/fasttext-vectors/wiki.en.zip" -O $PWD"/data/wiki.en.zip"
! unzip -q "data/wiki.en.zip" -d "data"

# Download test files
! wget "https://www.dropbox.com/s/7u56vtww6r6t37p/train_snli.txt.zip?dl=0" -O $PWD"/data/train_snli.txt.zip"
! unzip -q "data/train_snli.txt.zip" -d "data"
# Out:
# --2018-05-15 20:31:30--  https://s3-us-west-1.amazonaws.com/fasttext-vectors/wiki.en.zip
# Resolving s3-us-west-1.amazonaws.com (s3-us-west-1.amazonaws.com)... 52.219.24.57
# Connecting to s3-us-west-1.amazonaws.com (s3-us-west-1.amazonaws.com)|52.219.24.57|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 10356881291 (9.6G) [application/zip]
# Saving to: ‘/content/deep-siamese-text-similarity/data/wiki.en.zip’
#
# ty/data/wiki.en.zip  15%[==>                 ]   1.50G  41.0MB/s    eta 3m 40s
# xt-similarity/data/  99%[==================> ]   9.64G  29.5MB/s    eta 0s
# /content/deep-siame 100%[===================>]   9.65G  29.4MB/s    in 6m 10s
#
# 2018-05-15 20:37:40 (26.7 MB/s) - ‘/content/deep-siamese-text-similarity/data/wiki.en.zip’ saved [10356881291/10356881291]

# %%
! head -15 data/wiki.en.vec
# Out:
# 2519370 300
# ...

# %%
! python train.py --is_char_based False --training_files data/train_snli.txt --word2vec_model data/wiki.en.vec --side1_dropout 0.8 --side2_dropout 1.0 --side1_hidden_units 75 --side2_hidden_units 25
# Out:
# Parameters:
# ALLOW_SOFT_PLACEMENT=True
# BATCH_SIZE=64
# CHECKPOINT_EVERY=1000
# EMBEDDING_DIM=300
# EVALUATE_EVERY=1000
# IS_CHAR_BASED=False
# L2_REG_LAMBDA=0.0
# LOG_DEVICE_PLACEMENT=False
# NUM_EPOCHS=300
# SIDE1_DROPOUT=0.8
# SIDE1_HIDDEN_UNITS=75
# SIDE1_LAYERS=3
# SIDE2_DROPOUT=1.0
# SIDE2_HIDDEN_UNITS=25
# SIDE2_LAYERS=3
# SIDES_OUT_UNITS=50
# TRAINING_FILES=data/train_snli.txt
# WORD2VEC_FORMAT=text
# WORD2VEC_MODEL=data/wiki.en.vec
#
# Loading training data from data/train_snli.txt
# Building vocabulary
# Length of loaded vocabulary =31337
# dumping validation 0
# Train/Dev split for data/train_snli.txt: 330635/36738
# Loading W2V data...
# ('loaded word2vec len ', 2519371)
# starting graph def
# 2018-05-15 21:24:06.490437: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.1 instructions, but these are available on your machine and could speed up CPU computations.
# ...
